# %%
import sys
import os

sys.path.append(os.path.abspath('../scripts'))

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd

df = pd.read_csv("../data/processed/CleanedMachineLearningRating_v3.csv")
# Out:
# C:\Users\redie\AppData\Local\Temp\ipykernel_5352\952855381.py:3: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/processed/CleanedMachineLearningRating_v3.csv")

# %%
df[['CapitalOutstanding', 'TermFrequency', 'CalculatedPremiumPerTerm',
       'TotalClaims']].head()
# Out:
#   CapitalOutstanding TermFrequency  CalculatedPremiumPerTerm  TotalClaims
# 0           119300.0       Monthly                   25.0000          0.0
# 1           119300.0       Monthly                   25.0000          0.0
# 2           119300.0       Monthly                   25.0000          0.0
# 3           119300.0       Monthly                  584.6468          0.0
# 4           119300.0       Monthly                  584.6468          0.0

# %% [markdown]
# In some rows decimals are replaced with commas, the code below identifies and corrects that

# %%
# Out:
# 0

# %%
# Out:
# 0

# %%
print(len(df))
# Out:
# 949041

# %%
print(len(df))
# Out:
# 949041

# %%
import eda as eda
cols_to_plot = ['kilowatts', 'cubiccapacity', 'CapitalOutstanding', 'SumInsured', 'CalculatedPremiumPerTerm',
                'TotalPremium', 'TotalClaims']

for col in cols_to_plot:
    eda.plot_histogram_distributions(df, col, 50)

# %%
import eda as eda

# Plot categorical variables
cols_to_plot = ['TermFrequency','CoverCategory', 'CoverType', 'CoverGroup', 'Section','StatutoryClass']

for col in cols_to_plot:
    eda.plot_count_distributions(df, col)

# %%
cols_to_plot = ['IsVATRegistered', 'LegalType', 'Language', 'AccountType',
       'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone', 
       'SubCrestaZone', 'ItemType']
for col in cols_to_plot:
    eda.plot_count_distributions(df, col)

# %%
cols_to_plot = ['VehicleType','RegistrationYear', 'Model', 'Cylinders', 'TrackingDevice', 'AlarmImmobiliser']
for col in cols_to_plot:
    eda.plot_count_distributions(df, col)
