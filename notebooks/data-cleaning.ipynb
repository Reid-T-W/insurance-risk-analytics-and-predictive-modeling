# %%
import sys
import os

sys.path.append(os.path.abspath('../scripts'))

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Load Data
import pandas as pd

df = pd.read_csv("../data/raw/MachineLearningRating_v3_csv.csv")
# Out:
# C:\Users\redie\AppData\Local\Temp\ipykernel_7816\3838199136.py:4: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/MachineLearningRating_v3_csv.csv")

# %%
# Viewing Top 5 Data
df.head()
# Out:
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# 3              Close Corporation    Mr  English  First National Bank
# 4              Close Corporation    Mr  English  First National Bank
#
#        AccountType  ...                    ExcessSelected CoverCategory  \
# ...

# %%
# Viewing bottom 5 results
df.tail()
# Out:
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# 1000095                31520       389  2015-08-01 00:00:00            False
# 1000096                31519       389  2014-07-01 00:00:00            False
# 1000097                31519       389  2015-02-01 00:00:00            False
#
#         Citizenship   LegalType Title Language       Bank      AccountType  \
# 1000093          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000094          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000095          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000096          ZW  Individual    Mr  English  ABSA Bank  Savings account
# 1000097          ZW  Individual    Mr  English  ABSA Bank  Savings account
#
# ...

# %%
# Describe Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %%
# Describe numeric columns
df.select_dtypes(include = 'number').describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# ...

# %%
# Check missing values
import preprocess as pp

# Total number of missing values in the dataset
print("Null and missing value count")
print("----------------------------------------")
# No of null values and empty string in each column
display(pp.count_empty_or_null(df))
# Out:
# Null and missing value count
# ----------------------------------------
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                  895210
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# ...

# %%
print("Null and missing value percentage")
print("----------------------------------------")
print("----------------------------------------")
# No of null values and empty string in each column
display(pp.percent_null_and_empty_string(df))
# Out:
# Null and missing value percentage
# ----------------------------------------
# ----------------------------------------
# UnderwrittenCoverID           0.000000
# PolicyID                      0.000000
# TransactionMonth              0.000000
# IsVATRegistered               0.000000
# Citizenship                  89.512228
# LegalType                     0.000000
# Title                         0.000000
# Language                      0.000000
# Bank                         14.594670
# AccountType                   4.022806
# MaritalStatus                 0.825819
# Gender                        0.953507
# Country                       0.000000
# Province                      0.000000
# PostalCode                    0.000000
# MainCrestaZone                0.000000
# SubCrestaZone                 0.000000
# ItemType                      0.000000
# mmcode                        0.055195
# VehicleType                   0.055195
# RegistrationYear              0.000000
# ...

# %%
# Drop columns with missing values greater than 5%
df = df.drop(['Bank', 'Citizenship', 'CustomValueEstimate', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'NumberOfVehiclesInFleet'], axis = 1)

# %%
# no of records in df
print("No of records in data frame")
print(len(df))
# Out:
# No of records in data frame
# 1000098

# %%
# Checking count of records with missing values less than 5%
null_percent = df.isnull().mean() * 100
cols_with_nulls = null_percent[null_percent > 0]
display(cols_with_nulls)
# Out:
# AccountType           4.022806
# MaritalStatus         0.825819
# Gender                0.953507
# mmcode                0.055195
# VehicleType           0.055195
# make                  0.055195
# Model                 0.055195
# Cylinders             0.055195
# cubiccapacity         0.055195
# kilowatts             0.055195
# bodytype              0.055195
# NumberOfDoors         0.055195
# VehicleIntroDate      0.055195
# CapitalOutstanding    0.000200
# dtype: float64

# %%
# Dropping rows with any type of missing values
df_cleaned = df.dropna()

# %%
# Checking count of records with missing values less than 5%
print("no of missing values in each column after cleaning")
null_percent = df_cleaned.isnull().mean() * 100
cols_with_nulls = null_percent[null_percent > 0]
display(cols_with_nulls)

print("No of Records in cleaned dataframe")
print(f"No of Records in cleaned dataframe {len(df_cleaned)}")
# Out:
# no of missing values in each column after cleaning
# Series([], dtype: float64)
# No of Records in cleaned dataframe
# No of Records in cleaned dataframe 949327

# %%
# Clean wrong records
# Some capital outstanding records have commas as decimals
# Replace them with dots
invalid_rows = df[df['CapitalOutstanding'].astype(str).str.contains(',', regex=False)]
print("No of invalid rows (containing commas) before correction: ", len(invalid_rows))

df['CapitalOutstanding'] = df['CapitalOutstanding'].astype(str).str.replace(',', '.')
df['CapitalOutstanding'] = pd.to_numeric(df['CapitalOutstanding'], errors='coerce')
invalid_rows = df[df['CapitalOutstanding'].astype(str).str.contains(',', regex=False)]

print("No of invalid rows (containing commas) after correction: ", len(invalid_rows['CapitalOutstanding']))
# Out:
# No of invalid rows (containing commas) before correction:  0
# No of invalid rows (containing commas) after correction:  0

# %%
# Clean wrong records
# Some total premium values have -ve values, which should not be
length = len(df[df["TotalPremium"] < 0])
print(f"total values less than 0 {length} before fix")

df = df[df['TotalPremium'] >= 0]

length = len(df[df["TotalPremium"] < 0])
print(f"total values less than 0 {length} after fix")
# Out:
# total values less than 0 288 before fix
# total values less than 0 0 after fix

# %%
# Export cleaned data
df_cleaned.to_csv("../data/processed/CleanedMachineLearningRating_v3.csv")
